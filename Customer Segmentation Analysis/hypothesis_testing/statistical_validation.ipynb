# %%
import pandas as pd
import numpy as np

from scipy.stats import ttest_ind
from scipy.stats import chi2_contingency

# %%
df = pd.read_csv("final_cleaned_dataset.csv")

# %%
df.head()

# %%
df.info()

# %% [markdown]
# Hypothesis Test 1 — Independent T-Test
# Business Question
#
# Do Online and Offline sales channels generate different average revenue?

# %%
df['Sales_Channel'].unique()

# %%
online = df[df['Sales_Channel'] == 'Online']['Total_Amount']

offline = df[df['Sales_Channel'] == 'Offline']['Total_Amount']

# %% [markdown]
# Perform T test

# %%
t_stat, p_value = ttest_ind(
    online,
    offline,
    equal_var=False
)

print("T Statistic:", t_stat)
print("P Value:", p_value)

# %% [markdown]
# Interpretation

# %%
alpha = 0.05

if p_value < alpha:
    print("Reject Null Hypothesis")
    print("Significant difference exists")
else:
    print("Fail to Reject Null Hypothesis")
    print("No significant difference exists")

# %% [markdown]
# Hypothesis Test 2 — Chi-Square Test
# Business Question
#
# Is Payment Method associated with Sales Channel?

# %% [markdown]
# Create Contingency Table

# %%
table = pd.crosstab(
    df['Payment_Method'],
    df['Sales_Channel']
)

table

# %% [markdown]
# Perform Chi-Square Test

# %%
chi2, p, dof, expected = chi2_contingency(table)

print("Chi Square:", chi2)
print("P Value:", p)

# %% [markdown]
# Interpretation

# %%
alpha = 0.05

if p < alpha:
    print("Reject Null Hypothesis")
    print("Variables are associated")
else:
    print("Fail to Reject Null Hypothesis")
    print("Variables are independent")

# %% [markdown]
# # Statistical Validation Summary
#
# ## T-Test Result
# The analysis evaluated whether Online and Offline sales channels generate different average revenue.
#
# Based on the p-value, the hypothesis test determined whether the observed difference is statistically significant.
#
# ## Chi-Square Test Result
# The analysis examined the relationship between Payment Method and Sales Channel.
#
# Based on the p-value, the test determined whether these variables are associated or independent.
#
# ## Business Impact
# These statistical tests provide confidence that the identified business insights are supported by data rather than random variation.
